# %%
import pandas as pd
import numpy as np

# %%
import re
from collections import defaultdict, Counter
import math
import pandas as pd
import numpy as np

# To read the csv files
df_train = pd.read_csv('/content/games_train_sheets - games-train.csv')
df_test = pd.read_csv('/content/games_test_sheets - games-test.csv')

# To clean the NAN values
cleaned_train_df = df_train.dropna()
cleaned_test_df = df_test.dropna()

# Another logic to clean text$, handle NaN and remove non-alphabetic characters
def preprocess_text(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    text = re.sub(r"[^a-zäöüß ]", "", text)
    return text

# Preprocess train data
cleaned_train_df["Review text"] = cleaned_train_df["Review text"].apply(preprocess_text)
cleaned_train_df["Class of review (good or bad)"] = cleaned_train_df["Class of review (good or bad)"].map({"gut": 1, "bad": 0})

# Preprocess test data
cleaned_test_df["Review text"] = cleaned_test_df["Review text"].apply(preprocess_text)
cleaned_test_df["Class of review (good or bad)"] = cleaned_test_df["Class of review (good or bad)"].map({"gut": 1, "bad": 0})

# Running the code in a subset of actual data (Because it was very slow when tried on the whole dataset)
train_data = cleaned_train_df.head(160)
test_data = cleaned_test_df.head(40)

# Naive Bayes classifier logic from scratch
class NaiveBayesClassifier:
    def __init__(self, alpha=1.0):
        self.alpha = alpha
        self.class_counts = defaultdict(int)
        self.term_counts = defaultdict(lambda: defaultdict(int))
        self.vocab = set()
        self.total_docs = 0

    def train(self, data, text_col, label_col):
        for _, row in data.iterrows():
            label = row[label_col]
            text = row[text_col]
            self.class_counts[label] += 1
            self.total_docs += 1
            words = text.split()
            for word in words:
                self.vocab.add(word)
                self.term_counts[label][word] += 1

    def predict(self, text):
        words = text.split()
        scores = {}
        for c in self.class_counts:
            log_prior = math.log(self.class_counts[c] / self.total_docs)
            log_likelihood = 0
            for word in words:
                word_count = self.term_counts[c][word]
                total_count = sum(self.term_counts[c].values())
                likelihood = (word_count + self.alpha) / (total_count + self.alpha * len(self.vocab))
                log_likelihood += math.log(likelihood)
            scores[c] = log_prior + log_likelihood
        return max(scores, key=scores.get)

    def top_terms(self, top_n=100):
        class_top_terms = {}
        for c in self.class_counts:
            terms = self.term_counts[c]
            total_count = sum(terms.values())
            term_probs = {term: (count + self.alpha) / (total_count + self.alpha * len(self.vocab))
                          for term, count in terms.items()}
            sorted_terms = sorted(term_probs.items(), key=lambda x: x[1], reverse=True)[:top_n]
            class_top_terms[c] = sorted_terms
        return class_top_terms

# To instantiate and train classifier
nb = NaiveBayesClassifier(alpha=1.0)
nb.train(train_data, "Review text", "Class of review (good or bad)")

# Predict on test data
test_data["Predicted"] = test_data["Review text"].apply(nb.predict)

# Output predictions
print("Predictions on Test Data:")
print(test_data)

# To print top terms for each class
print("\nTop Terms for Each Class:")
top_terms = nb.top_terms(top_n=100)
for c, terms in top_terms.items():
    print(f"Class {c}:")
    for term, prob in terms:
        print(f"{term}: {prob:.4f}")
# Out:
# <ipython-input-12-1325389d6019>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_train_df["Review text"] = cleaned_train_df["Review text"].apply(preprocess_text)
# <ipython-input-12-1325389d6019>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_train_df["Class of review (good or bad)"] = cleaned_train_df["Class of review (good or bad)"].map({"gut": 1, "bad": 0})
# <ipython-input-12-1325389d6019>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_test_df["Review text"] = cleaned_test_df["Review text"].apply(preprocess_text)
# <ipython-input-12-1325389d6019>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_test_df["Class of review (good or bad)"] = cleaned_test_df["Class of review (good or bad)"].map({"gut": 1, "bad": 0})
# <ipython-input-12-1325389d6019>:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data["Predicted"] = test_data["Review text"].apply(nb.predict)
# Predictions on Test Data:
#           Title of game  Class of review (good or bad)  \
# 1          Die Simpsons                            1.0
# 2          Die Simpsons                            1.0
# 3          Die Simpsons                            1.0
# 4        Subway Surfers                            1.0
# 6          Die Simpsons                            1.0
# 7               Hay Day                            NaN
# 8          Die Simpsons                            1.0
# 9           Angry Birds                            1.0
# 10              Hay Day                            1.0
# 11         Die Simpsons                            1.0
# 12         Die Simpsons                            1.0
# 14          Angry Birds                            1.0
# 15       Bike Race Free                            1.0
# 16              Hay Day                            1.0
# 17       Subway Surfers                            1.0
# 18       Subway Surfers                            1.0
# 19       Subway Surfers                            1.0
# 21  Call Of Duty Heroes                            1.0
# 22              Hay Day                            1.0
# 23              Hay Day                            1.0
# 24         Die Simpsons                            NaN
# 25              Hay Day                            1.0
# 26       Subway Surfers                            1.0
# 28       Bike Race Free                            1.0
# 29         Die Simpsons                            NaN
# 30         Die Simpsons                            NaN
# 32       Subway Surfers                            1.0
# 33          Farmville 2                            1.0
# 35              Hay Day                            1.0
# 36       Subway Surfers                            1.0
# 38       Subway Surfers                            1.0
# 39              Hay Day                            1.0
# 42  Call Of Duty Heroes                            1.0
# 43       Subway Surfers                            1.0
# 45          Farmville 2                            1.0
# 47              Hay Day                            1.0
# 48       Subway Surfers                            1.0
# 51         Die Simpsons                            1.0
# 52         Die Simpsons                            1.0
# 53              Hay Day                            1.0
#
#                             Title of review  \
# 1                              Buchi0202136
# 2                         Suchtgefähr :) !!
# 3                       Dauerhafter Spaß...
# 4                                     Great
# 6                                       Top
# 7                  Ansich ganz nett aber...
# 8                                     Geilo
# 9                                     Vadim
# 10                      Macht total süchtig
# 11                                     Cool
# 12  Die beste App sowie sehr unterhaltsam..
# 14                                    super
# 15                                     TOLL
# 16                                   HayDay
# 17                Vorsicht macht süchtig!!!
# 18                               Galaxy S4,
# 19                             Tolles Spiel
# 21                                     Cool
# 22                                     Cool
# 23                             Kartenteile!
# 24     Nach dem update tut sich nichts mehr
# 25                           nicht schlecht
# 26                                      Gut
# 28                               Super game
# 29                        Nichts geht mehr!
# 30                            Ehrlich?! o_O
# 32    Bei mir lagd bisschen aber sonst geil
# 33                             Finde es gut
# 35                               Geht super
# 36                                     Geil
# 38               Müsst ihr euch runterladen
# 39                                   HayDay
# 42                           Nicht schlecht
# 43                                     Cool
# 45                               Tolle farm
# 47                                   GEIL!!
# 48                                   Cooles
# 51                              Super spiel
# 52                                Nachtbarn
# 53         Zu wenig Erweiterungsmaterial!!!
#
#                                           Review text  Predicted
# 1                  suche noch freunde zum hinzufuegen        1.0
# 2   ich find das spiel gutman muss nicht permanent...        1.0
# 3    durch immer neue events schon   jahre dabei  ...        1.0
# 4   i like the game but near the last update it st...        NaN
# 6                                               spiel        1.0
# 7   ansich ein nettes spiel jedoch warmen alles ha...        1.0
# 8   ich hab das s läuft es macht abartig viel spaß...        1.0
# 9                                                 top        1.0
# 10  das beste farmerspiel alles zeitenes macht meg...        1.0
# 11                                               cool        1.0
# 12  freue mich auf nette nachbarn cubiccienfuego b...        1.0
# 14                   sehr kurzweilig und unterhaltsam        1.0
# 15                                         gutes game        1.0
# 16                                achtung suchtgefahr        1.0
# 17                       das ist so ein geiles spiel         1.0
# 18                         top spiel macht mega spass        1.0
# 19  es macht einfach spaß und ist ein gutes gelege...        1.0
# 21                                               cool        1.0
# 22                                                lol        1.0
# 23  ich wollte mal fragen ob die kartenteile die m...        1.0
# 24  habs update gestern runter geladen heute mitta...        NaN
# 25  dass spiel ist wirklich nicht schlecht blos da...        1.0
# 26            alles gut aber manchmal kommen da hacks        1.0
# 28                                          best game        1.0
# 29  kann seit  tagen nicht mehr spielen immer wied...        NaN
# 30  ich das euer ernst habe das update gefahren un...        1.0
# 32  leute die sagen dass das update schlecht is si...        1.0
# 33                               ist ein tolles spiel        1.0
# 35               keine leggs und tolles spiel  sterne        1.0
# 36                                               geil        1.0
# 38  es ist wirklich wirklich wirklich wirklich wir...        1.0
# 39                    super wird nie lanweilig klasse        1.0
# 42  es hat eine tolle grafik macht spaß es zu spie...        1.0
# 43  macht mega spaß und vertreibt die zeit bei lan...        1.0
# 45           super farm spiel  suchtfaktor sehr hoch         1.0
# 47                                        geiloooooo         1.0
# 48                                              spiel        1.0
# 51  macht echt laune  hätte noch platz für nachbar...        1.0
# 52                      ihr findet mich unter eeeljot        1.0
# 53  hay day ist ein topp spiel das update mit neue...        1.0
#
# Top Terms for Each Class:
# Class 1.0:
# ist: 0.0218
# es: 0.0197
# das: 0.0197
# spiel: 0.0161
# ich: 0.0140
# und: 0.0114
# aber: 0.0104
# cool: 0.0099
# die: 0.0099
# macht: 0.0093
# man: 0.0088
# nur: 0.0078
# geil: 0.0078
# noch: 0.0073
# einfach: 0.0073
# sehr: 0.0073
# spaß: 0.0073
# ein: 0.0067
# echt: 0.0057
# auch: 0.0057
# nicht: 0.0057
# mama: 0.0057
# super: 0.0052
# in: 0.0047
# so: 0.0047
# auf: 0.0047
# mich: 0.0042
# was: 0.0042
# bitte: 0.0042
# wenn: 0.0036
# den: 0.0036
# wieder: 0.0036
# muss: 0.0036
# gut: 0.0036
# mit: 0.0036
# richtig: 0.0031
# spiele: 0.0031
# kann: 0.0031
# dann: 0.0031
# zu: 0.0031
# sterne: 0.0031
# hat: 0.0031
# nachbarn: 0.0031
# finde: 0.0031
# alle: 0.0031
# der: 0.0026
# wäre: 0.0026
# liebe: 0.0026
# app: 0.0026
# viel: 0.0026
# sonst: 0.0026
# alles: 0.0026
# habe: 0.0026
# schnell: 0.0026
# wird: 0.0026
# bin: 0.0026
# also: 0.0026
# sich: 0.0026
# spielen: 0.0026
# sind: 0.0026
# game: 0.0026
# zeitvertreib: 0.0026
# wer: 0.0026
# suche: 0.0026
 0.0026
# suche: 0.0013
# noch: 0.0013
# freunde: 0.0013
# zum: 0.0013
# hinzufuegen: 0.0013
# find: 0.0013
# das: 0.0013
# spiel: 0.0013
# gutman: 0.0013
# muss: 0.0013
# permanent: 0.0013
# spielen: 0.0013
# tolle: 0.0013
# events: 0.0013
# hält: 0.0013
# einen: 0.0013
# bei: 0.0013
# spiellaunewird: 0.0013
# also: 0.0013
# nie: 0.0013
# langweilig: 0.0013
# einziges: 0.0013
# was: 0.0013
# anmerken: 0.0013
# möchte: 0.0013
# schade: 0.0013
# istdas: 0.0013
# objekte: 0.0013
# in: 0.0013
# jede: 0.0013
# richtung: 0.0013
# drehen: 0.0013
# zb: 0.0013
# bänke: 0.0013
# die: 0.0013
# sind: 0.0013
# nur: 0.0013
# möglich: 0.0013
# zu: 0.0013
# drehenaber: 0.0013
# sonst: 0.0013
# alles: 0.0013
# super: 0.0013
# durch: 0.0013
# immer: 0.0013
# neue: 0.0013
# schon: 0.0013
# jahre: 0.0013
# dabei: 0.0013
# wieder: 0.0013
# platz: 0.0013
# für: 0.0013
# nachbarn: 0.0013
# jesaya: 0.0013
# i: 0.0013
# like: 0.0013
# the: 0.0013
# game: 0.0013
# but: 0.0013
# near: 0.0013
# last: 0.0013
# update: 0.0013
# it: 0.0013
# stops: 0.0013
# often: 0.0013
# so: 0.0013
# your: 0.0013
# franzie: 0.0013
# ansich: 0.0013
# ein: 0.0013
# nettes: 0.0013
# jedoch: 0.0013
# warmen: 0.0013
# hat: 0.0013
# wie: 0.0013
# bienen: 0.0013
# usw: 0.0013
# gibt: 0.0013
# es: 0.0013
# definitiv: 0.0013
# Class nan:
# ich: 0.0051
# und: 0.0038
# musste: 0.0025
# smartphone: 0.0025
# zurücksetzen: 0.0025
# alles: 0.0025
# neu: 0.0025
# installieren: 0.0025
# jetzt: 0.0025
# kann: 0.0025
# wieder: 0.0025
# bei: 0.0025
# null: 0.0025
# anfangen: 0.0025
# da: 0.0025
# keine: 0.0025
# verbindung: 0.0025
# zu: 0.0025
# facebook: 0.0025
# google: 0.0025
# play: 0.0025
# möglich: 0.0025
# ist: 0.0025
# danke: 0.0025
# zynga: 0.0025
# wird: 0.0025
# langsam: 0.0025
# zeit: 0.0025
# dass: 0.0025
# dieses: 0.0025
# spiel: 0.0025
# aus: 0.0025
# dem: 0.0025
# playstore: 0.0025
# verschwindet: 0.0025
# ps: 0.0025
# war: 0.0025
# bereits: 0.0025
# level: 0.0025
# suche: 0.0013
# noch: 0.0013
# freunde: 0.0013
# zum: 0.0013
# hinzufuegen: 0.0013
# find: 0.0013
# das: 0.0013
# gutman: 0.0013
# muss: 0.0013
# nicht: 0.0013
# permanent: 0.0013
# spielen: 0.0013
# tolle: 0.0013
# events: 0.0013
# hält: 0.0013
# einen: 0.0013
# spiellaunewird: 0.0013
# also: 0.0013
# nie: 0.0013
# langweilig: 0.0013
# einziges: 0.0013
# was: 0.0013
# anmerken: 0.0013
# möchte: 0.0013
# schade: 0.0013
# istdas: 0.0013
# man: 0.0013
# objekte: 0.0013
# in: 0.0013
# jede: 0.0013
# richtung: 0.0013
# drehen: 0.0013
# zb: 0.0013
# bänke: 0.0013
# die: 0.0013
# sind: 0.0013
# nur: 0.0013
# drehenaber: 0.0013
# sonst: 0.0013
# super: 0.0013
# durch: 0.0013
# immer: 0.0013
# neue: 0.0013
# schon: 0.0013
# jahre: 0.0013
# dabei: 0.0013
# platz: 0.0013
# für: 0.0013
# nachbarn: 0.0013
# jesaya: 0.0013
# i: 0.0013
# like: 0.0013
# the: 0.0013
# game: 0.0013
# but: 0.0013
# near: 0.0013
# last: 0.0013
# update: 0.0013
# it: 0.0013
# stops: 0.0013
# often: 0.0013
# Class nan:
# es: 0.0064
# ist: 0.0051
# ich: 0.0051
# das: 0.0038
# spiel: 0.0038
# eigendlich: 0.0025
# doof: 0.0025
# jedenfalls: 0.0025
# für: 0.0025
# mich: 0.0025
# musste: 0.0025
# löschen: 0.0025
# weil: 0.0025
# immer: 0.0025
# abgestürzt: 0.0025
# und: 0.0025
# wo: 0.0025
# wieder: 0.0025
# herunterladen: 0.0025
# wollte: 0.0025
# ging: 0.0025
# nicht: 0.0025
# echt: 0.0025
# belämmert: 0.0025
# mag: 0.0025
# dieses: 0.0025
# ganz: 0.0025
# dolle: 0.0025
# aber: 0.0025
# eben: 0.0025
# doooooffffff: 0.0025
# suche: 0.0013
# noch: 0.0013
# freunde: 0.0013
# zum: 0.0013
# hinzufuegen: 0.0013
# find: 0.0013
# gutman: 0.0013
# muss: 0.0013
# permanent: 0.0013
# spielen: 0.0013
# tolle: 0.0013
# events: 0.0013
# hält: 0.0013
# einen: 0.0013
# bei: 0.0013
# spiellaunewird: 0.0013
# also: 0.0013
# nie: 0.0013
# langweilig: 0.0013
# einziges: 0.0013
# was: 0.0013
# anmerken: 0.0013
# möchte: 0.0013
# schade: 0.0013
# istdas: 0.0013
# man: 0.0013
# objekte: 0.0013
# in: 0.0013
# jede: 0.0013
# richtung: 0.0013
# drehen: 0.0013
# kann: 0.0013
# zb: 0.0013
# bänke: 0.0013
# die: 0.0013
# sind: 0.0013
# nur: 0.0013
# möglich: 0.0013
# zu: 0.0013
# drehenaber: 0.0013
# sonst: 0.0013
# alles: 0.0013
# super: 0.0013
# durch: 0.0013
# neue: 0.0013
# schon: 0.0013
# jahre: 0.0013
# dabei: 0.0013
# platz: 0.0013
# nachbarn: 0.0013
# jesaya: 0.0013
# i: 0.0013
# like: 0.0013
# the: 0.0013
# game: 0.0013
# but: 0.0013
# near: 0.0013
# last: 0.0013
# update: 0.0013
# it: 0.0013
# stops: 0.0013
# often: 0.0013
# so: 0.0013
# your: 0.0013
# franzie: 0.0013
# ansich: 0.0013
# ein: 0.0013
# nettes: 0.0013
# jedoch: 0.0013
# Class nan:
# es: 0.0027
# kakt: 0.0027
# die: 0.0027
# ganze: 0.0027
# zeit: 0.0027
# ab: 0.0027
# suche: 0.0013
# noch: 0.0013
# freunde: 0.0013
# zum: 0.0013
# hinzufuegen: 0.0013
# ich: 0.0013
# find: 0.0013
# das: 0.0013
# spiel: 0.0013
# gutman: 0.0013
# muss: 0.0013
# nicht: 0.0013
# permanent: 0.0013
# spielen: 0.0013
# und: 0.0013
# tolle: 0.0013
# events: 0.0013
# hält: 0.0013
# einen: 0.0013
# bei: 0.0013
# spiellaunewird: 0.0013
# also: 0.0013
# nie: 0.0013
# langweilig: 0.0013
# einziges: 0.0013
# was: 0.0013
# anmerken: 0.0013
# möchte: 0.0013
# schade: 0.0013
# istdas: 0.0013
# man: 0.0013
# objekte: 0.0013
# in: 0.0013
# jede: 0.0013
# richtung: 0.0013
# drehen: 0.0013
# kann: 0.0013
# zb: 0.0013
# bänke: 0.0013
# sind: 0.0013
# nur: 0.0013
# möglich: 0.0013
# zu: 0.0013
# drehenaber: 0.0013
# sonst: 0.0013
# alles: 0.0013
# super: 0.0013
# durch: 0.0013
# immer: 0.0013
# neue: 0.0013
# schon: 0.0013
# jahre: 0.0013
# dabei: 0.0013
# wieder: 0.0013
# platz: 0.0013
# für: 0.0013
# nachbarn: 0.0013
# jesaya: 0.0013
# i: 0.0013
# like: 0.0013
# the: 0.0013
# game: 0.0013
# but: 0.0013
# near: 0.0013
# last: 0.0013
# update: 0.0013
# it: 0.0013
# stops: 0.0013
# often: 0.0013
# so: 0.0013
# your: 0.0013
# franzie: 0.0013
# ansich: 0.0013
# ein: 0.0013
# nettes: 0.0013
# jedoch: 0.0013
# warmen: 0.0013
# hat: 0.0013
# wie: 0.0013
# bienen: 0.0013
# usw: 0.0013
# gibt: 0.0013
# definitiv: 0.0013
# wenig: 0.0013
# äxte: 0.0013
# sollte: 0.0013
# sich: 0.0013
# ändern: 0.0013
# sterne: 0.0013
# ansonsten: 0.0013
# wird: 0.0013
# bald: 0.0013
# deinstalliert: 0.0013
# macht: 0.0013
# Class nan:
# naja: 0.0027
# suche: 0.0013
# noch: 0.0013
# freunde: 0.0013
# zum: 0.0013
# hinzufuegen: 0.0013
# ich: 0.0013
# find: 0.0013
# das: 0.0013
# spiel: 0.0013
# gutman: 0.0013
# muss: 0.0013
# nicht: 0.0013
# permanent: 0.0013
# spielen: 0.0013
# und: 0.0013
# tolle: 0.0013
# events: 0.0013
# hält: 0.0013
# einen: 0.0013
# bei: 0.0013
# spiellaunewird: 0.0013
# also: 0.0013
# nie: 0.0013
# langweilig: 0.0013
# einziges: 0.0013
# was: 0.0013
# anmerken: 0.0013
# möchte: 0.0013
# schade: 0.0013
# istdas: 0.0013
# man: 0.0013
# objekte: 0.0013
# in: 0.0013
# jede: 0.0013
# richtung: 0.0013
# drehen: 0.0013
# kann: 0.0013
# zb: 0.0013
# bänke: 0.0013
# die: 0.0013
# sind: 0.0013
# nur: 0.0013
# möglich: 0.0013
# zu: 0.0013
# drehenaber: 0.0013
# sonst: 0.0013
# alles: 0.0013
# super: 0.0013
# durch: 0.0013
# immer: 0.0013
# neue: 0.0013
# schon: 0.0013
# jahre: 0.0013
# dabei: 0.0013
# wieder: 0.0013
# platz: 0.0013
# für: 0.0013
# nachbarn: 0.0013
# jesaya: 0.0013
# i: 0.0013
# like: 0.0013
# the: 0.0013
# game: 0.0013
# but: 0.0013
# near: 0.0013
# last: 0.0013
# update: 0.0013
# it: 0.0013
# stops: 0.0013
# often: 0.0013
# so: 0.0013
# your: 0.0013
# franzie: 0.0013
# ansich: 0.0013
# ein: 0.0013
# nettes: 0.0013
# jedoch: 0.0013
# warmen: 0.0013
# hat: 0.0013
# wie: 0.0013
# bienen: 0.0013
# usw: 0.0013
# gibt: 0.0013
# es: 0.0013
# definitiv: 0.0013
# wenig: 0.0013
# äxte: 0.0013
# sollte: 0.0013
# sich: 0.0013
# ändern: 0.0013
# sterne: 0.0013
# ansonsten: 0.0013
# wird: 0.0013
# bald: 0.0013
# deinstalliert: 0.0013
# macht: 0.0013
# überhaupt: 0.0013
# keinen: 0.0013
# spaß: 0.0013
# Class nan:
# auf: 0.0050
# android: 0.0038
# ich: 0.0038
# das: 0.0038
# spiel: 0.0038
# nicht: 0.0038
# sich: 0.0038
# viele: 0.0025
# technische: 0.0025
# probleme: 0.0025
# nach: 0.0025
# update: 0.0025
# kann: 0.0025
# gar: 0.0025
# mehr: 0.0025
# meinem: 0.0025
# galaxy: 0.0025
# tab: 0.0025
# öffnen: 0.0025
# support: 0.0025
# hilft: 0.0025
# dem: 0.0025
# handy: 0.0025
# habe: 0.0025
# noch: 0.0025
# dort: 0.0025
# schließt: 0.0025
# permanent: 0.0025
# und: 0.0025
# hängt: 0.0025
# für: 0.0025
# die: 0.0025
# technik: 0.0025
# gibt: 0.0025
# es: 0.0025
# nur: 0.0025
# stern: 0.0025
# von: 0.0025
# mir: 0.0025
# spielspass: 0.0025
# hätte: 0.0025
# normalerweise: 0.0025
# volle: 0.0025
# punktzahl: 0.0025
# bekommen: 0.0025
# schade: 0.0025
# suche: 0.0013
# freunde: 0.0013
# zum: 0.0013
# hinzufuegen: 0.0013
# find: 0.0013
# gutman: 0.0013
# muss: 0.0013
# spielen: 0.0013
# tolle: 0.0013
# events: 0.0013
# hält: 0.0013
# einen: 0.0013
# bei: 0.0013
# spiellaunewird: 0.0013
# also: 0.0013
# nie: 0.0013
# langweilig: 0.0013
# einziges: 0.0013
# was: 0.0013
# anmerken: 0.0013
# möchte: 0.0013
# istdas: 0.0013
# man: 0.0013
# objekte: 0.0013
# in: 0.0013
# jede: 0.0013
# richtung: 0.0013
# drehen: 0.0013
# zb: 0.0013
# bänke: 0.0013
# sind: 0.0013
# möglich: 0.0013
# zu: 0.0013
# drehenaber: 0.0013
# sonst: 0.0013
# alles: 0.0013
# super: 0.0013
# durch: 0.0013
# immer: 0.0013
# neue: 0.0013
# schon: 0.0013
# jahre: 0.0013
# dabei: 0.0013
# wieder: 0.0013
# platz: 0.0013
# nachbarn: 0.0013
# jesaya: 0.0013
# i: 0.0013
# like: 0.0013
# the: 0.0013
# game: 0.0013
# but: 0.0013
# near: 0.0013
# last: 0.0013
# Class nan:
# wird: 0.0027
# nach: 0.0027
# einiger: 0.0027
# zeit: 0.0027
# langweilig: 0.0027
# aber: 0.0027
# voll: 0.0027
# suche: 0.0013
# noch: 0.0013
# freunde: 0.0013
# zum: 0.0013
# hinzufuegen: 0.0013
# ich: 0.0013
# find: 0.0013
# das: 0.0013
# spiel: 0.0013
# gutman: 0.0013
# muss: 0.0013
# nicht: 0.0013
# permanent: 0.0013
# spielen: 0.0013
# und: 0.0013
# tolle: 0.0013
# events: 0.0013
# hält: 0.0013
# einen: 0.0013
# bei: 0.0013
# spiellaunewird: 0.0013
# also: 0.0013
# nie: 0.0013
# einziges: 0.0013
# was: 0.0013
# anmerken: 0.0013
# möchte: 0.0013
# schade: 0.0013
# istdas: 0.0013
# man: 0.0013
# objekte: 0.0013
# in: 0.0013
# jede: 0.0013
# richtung: 0.0013
# drehen: 0.0013
# kann: 0.0013
# zb: 0.0013
# bänke: 0.0013
# die: 0.0013
# sind: 0.0013
# nur: 0.0013
# möglich: 0.0013
# zu: 0.0013
# drehenaber: 0.0013
# sonst: 0.0013
# alles: 0.0013
# super: 0.0013
# durch: 0.0013
# immer: 0.0013
# neue: 0.0013
# schon: 0.0013
# jahre: 0.0013
# dabei: 0.0013
# wieder: 0.0013
# platz: 0.0013
# für: 0.0013
# nachbarn: 0.0013
# jesaya: 0.0013
# i: 0.0013
# like: 0.0013
# the: 0.0013
# game: 0.0013
# but: 0.0013
# near: 0.0013
# last: 0.0013
# update: 0.0013
# it: 0.0013
# stops: 0.0013
# often: 0.0013
# so: 0.0013
# your: 0.0013
# franzie: 0.0013
# ansich: 0.0013
# ein: 0.0013
# nettes: 0.0013
# jedoch: 0.0013
# warmen: 0.0013
# hat: 0.0013
# wie: 0.0013
# bienen: 0.0013
# usw: 0.0013
# gibt: 0.0013
# es: 0.0013
# definitiv: 0.0013
# wenig: 0.0013
# äxte: 0.0013
# sollte: 0.0013
# sich: 0.0013
# ändern: 0.0013
# sterne: 0.0013
# ansonsten: 0.0013
# bald: 0.0013
# deinstalliert: 0.0013
# Class nan:
# ich: 0.0039
# nicht: 0.0039
# mehr: 0.0039
# seit: 0.0026
# eine: 0.0026
# woche: 0.0026
# hängt: 0.0026
# mein: 0.0026
# spiel: 0.0026
# komplett: 0.0026
# komme: 0.0026
# auf: 0.0026
# facebook: 0.0026
# rein: 0.0026
# kann: 0.0026
# meine: 0.0026
# ware: 0.0026
# verkaufen: 0.0026
# bitte: 0.0026
# tut: 0.0026
# was: 0.0026
# dagegen: 0.0026
# suche: 0.0013
# noch: 0.0013
# freunde: 0.0013
# zum: 0.0013
# hinzufuegen: 0.0013
# find: 0.0013
# das: 0.0013
# gutman: 0.0013
# muss: 0.0013
# permanent: 0.0013
# spielen: 0.0013
# und: 0.0013
# tolle: 0.0013
# events: 0.0013
# hält: 0.0013
# einen: 0.0013
# bei: 0.0013
# spiellaunewird: 0.0013
# also: 0.0013
# nie: 0.0013
# langweilig: 0.0013
# einziges: 0.0013
# anmerken: 0.0013
# möchte: 0.0013
# schade: 0.0013
# istdas: 0.0013
# man: 0.0013
# objekte: 0.0013
# in: 0.0013
# jede: 0.0013
# richtung: 0.0013
# drehen: 0.0013
# zb: 0.0013
# bänke: 0.0013
# die: 0.0013
# sind: 0.0013
# nur: 0.0013
# möglich: 0.0013
# zu: 0.0013
# drehenaber: 0.0013
# sonst: 0.0013
# alles: 0.0013
# super: 0.0013
# durch: 0.0013
# immer: 0.0013
# neue: 0.0013
# schon: 0.0013
# jahre: 0.0013
# dabei: 0.0013
# wieder: 0.0013
# platz: 0.0013
# für: 0.0013
# nachbarn: 0.0013
# jesaya: 0.0013
# i: 0.0013
# like: 0.0013
# the: 0.0013
# game: 0.0013
# but: 0.0013
# near: 0.0013
# last: 0.0013
# update: 0.0013
# it: 0.0013
# stops: 0.0013
# often: 0.0013
# so: 0.0013
# your: 0.0013
# franzie: 0.0013
# ansich: 0.0013
# ein: 0.0013
# nettes: 0.0013
# jedoch: 0.0013
# warmen: 0.0013
# hat: 0.0013
# wie: 0.0013
# bienen: 0.0013
# usw: 0.0013
# gibt: 0.0013

# %%
test_df = test_data = cleaned_test_df.head(10)



test_df["Class of review"] = test_df["Class of review (good or bad)"].map({"gut": 1, "bad": 0})

# To evaluate predictions
def evaluate_model(model, test_df):
    predictions = []
    for _, row in test_df.iterrows():
        predicted = model.predict(row["Review text"])
        predictions.append(predicted)

    test_df["Predicted"] = predictions

    # Initialize counters
    TP_good, FP_good, FN_good = 0, 0, 0
    TP_bad, FP_bad, FN_bad = 0, 0, 0

    for _, row in test_df.iterrows():
        true_label = row["Class of review (good or bad)"]
        predicted_label = row["Predicted"]

        if true_label == 1:  # True class: 'gut'
            if predicted_label == 1:
                TP_good += 1  # True Positive for 'gut'
            else:
                FN_good += 1  # False Negative for 'gut'
                FP_bad += 1  # False Positive for 'bad'
        else:  # True class: 'bad'
            if predicted_label == 0:
                TP_bad += 1  # True Positive for 'bad'
            else:
                FN_bad += 1  # False Negative for 'bad'
                FP_good += 1  # False Positive for 'gut'

    # Precision, Recall, F1-Score for good or 'gut'
    precision_good = TP_good / (TP_good + FP_good) if TP_good + FP_good > 0 else 0
    recall_good = TP_good / (TP_good + FN_good) if TP_good + FN_good > 0 else 0
    f1_good = (
        2 * precision_good * recall_good / (precision_good + recall_good)
        if precision_good + recall_good > 0
        else 0
    )

    # Precision, Recall, F1-Score for 'bad'
    precision_bad = TP_bad / (TP_bad + FP_bad) if TP_bad + FP_bad > 0 else 0
    recall_bad = TP_bad / (TP_bad + FN_bad) if TP_bad + FN_bad > 0 else 0
    f1_bad = (
        2 * precision_bad * recall_bad / (precision_bad + recall_bad)
        if precision_bad + recall_bad > 0
        else 0
    )

    # To return evaluation metrics and counts
    return {
        "TP_good": TP_good,
        "FP_good": FP_good,
        "FN_good": FN_good,
        "Precision_good": precision_good,
        "Recall_good": recall_good,
        "F1_good": f1_good,
        "TP_bad": TP_bad,
        "FP_bad": FP_bad,
        "FN_bad": FN_bad,
        "Precision_bad": precision_bad,
        "Recall_bad": recall_bad,
        "F1_bad": f1_bad,
        "Wrongly_classified": test_df[test_df["Class of review (good or bad)"] != test_df["Predicted"]],
    }
# Runnig evaluation
results = evaluate_model(nb, test_df)

# Print metrics
print("Evaluation Results:")
print(f"Precision (good): {results['Precision_good']:.2f}")
print(f"Recall (good): {results['Recall_good']:.2f}")
print(f"F1-Score (good): {results['F1_good']:.2f}")
print(f"Precision (bad): {results['Precision_bad']:.2f}")
print(f"Recall (bad): {results['Recall_bad']:.2f}")
print(f"F1-Score (bad): {results['F1_bad']:.2f}")
print(f"TP (good): {results['TP_good']}, FP (good): {results['FP_good']}, FN (good): {results['FN_good']}")
print(f"TP (bad): {results['TP_bad']}, FP (bad): {results['FP_bad']}, FN (bad): {results['FN_bad']}")

# To print wrongly classified instances
print("\nWrongly Classified Instances:")
print(results["Wrongly_classified"])
# Out:
# Evaluation Results:
# Precision (good): 0.89
# Recall (good): 0.89
# F1-Score (good): 0.89
# Precision (bad): 0.00
# Recall (bad): 0.00
# F1-Score (bad): 0.00
# TP (good): 8, FP (good): 1, FN (good): 1
# TP (bad): 0, FP (bad): 1, FN (bad): 1
#
# Wrongly Classified Instances:
#     Title of game  Class of review (good or bad)           Title of review  \
# 4  Subway Surfers                            1.0                     Great
# 7         Hay Day                            NaN  Ansich ganz nett aber...
#
#                                          Review text  Class of review  \
# 4  i like the game but near the last update it st...              NaN
# 7  ansich ein nettes spiel jedoch warmen alles ha...              NaN
#
#    Predicted
# 4        NaN
# 7        1.0
# <ipython-input-9-3f7f4165fc13>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["Class of review"] = test_df["Class of review (good or bad)"].map({"gut": 1, "bad": 0})
# <ipython-input-9-3f7f4165fc13>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["Predicted"] = predictions
